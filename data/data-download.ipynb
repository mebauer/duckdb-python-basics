# %%
import pandas as pd
import requests

# %%
ls
# Out:
# data-dictionary.xlsx      green-infrastructure.csv  out.parquet
# data-download.ipynb       out.csv

# %% [markdown]
# # Download Green Infrastructure Data

# %%
# preview data
path = "https://data.cityofnewyork.us/api/views/bs59-f3nu/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(path)

print("shape of data: {}".format(df.shape))
df.head()
# Out:
# shape of data: (14718, 30)
#                                        the_geom  Asset_ID GI_ID DEP_Contra  \
# 0  POINT (-73.81167623024226 40.69138622900597)     94002    1A  GQJA03-02
# 1  POINT (-73.81228577606385 40.69238458134393)     94012  GS6A  GQJA03-02
# 2   POINT (-73.8122344420821 40.69312522070409)     94017  GS8C  GQJA03-02
# 3    POINT (-73.8120597400255 40.6931738947353)     94019  GS8E  GQJA03-02
# 4  POINT (-73.81310191327061 40.69279332424906)     94021   10A  GQJA03-02
#
#   DEP_Cont_1 Row_Onsite           Project_Na Asset_Type  \
# 0          2        ROW  DDC JAM-003 Phase 2       ROWB
# 1          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 2          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 3          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 4          2        ROW  DDC JAM-003 Phase 2       ROWB
#
#                            Status    Asset_X_Co  ...  Asset_Leng Asset_Widt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14718 entries, 0 to 14717
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   the_geom    14718 non-null  object
#  1   Asset_ID    14718 non-null  int64
#  2   GI_ID       14718 non-null  object
#  3   DEP_Contra  14718 non-null  object
#  4   DEP_Cont_1  14718 non-null  object
#  5   Row_Onsite  14718 non-null  object
#  6   Project_Na  14718 non-null  object
#  7   Asset_Type  14718 non-null  object
#  8   Status      14718 non-null  object
#  9   Asset_X_Co  14718 non-null  float64
#  10  Asset_Y_Co  14718 non-null  float64
#  11  Borough     14718 non-null  object
#  12  Sewer_Type  14718 non-null  object
#  13  Outfall     14718 non-null  object
#  14  NYC_Waters  14718 non-null  object
#  15  BBL         14718 non-null  int64
#  16  Secondary_  14718 non-null  int64
#  17  Community_  14718 non-null  int64
#  18  City_Counc  14718 non-null  int64
# ...

# %%
df.describe()
# Out:
#             Asset_ID    Asset_X_Co     Asset_Y_Co           BBL    Secondary_  \
# count   14718.000000  1.471800e+04   14718.000000  1.471800e+04  1.471800e+04
# mean   153042.997146  1.018221e+06  197258.927566  3.447610e+09  4.519417e+08
# std     30486.743026  1.588688e+04   21104.666950  7.024183e+08  1.160259e+09
# min     94002.000000  9.136176e+05  122392.154050  1.000000e+09  0.000000e+00
# 25%    125456.500000  1.006631e+06  182983.847500  3.037630e+09  0.000000e+00
# 50%    158172.500000  1.017716e+06  190914.426600  3.081790e+09  0.000000e+00
# 75%    182848.750000  1.031467e+06  209677.152500  4.056820e+09  0.000000e+00
# max    190803.000000  1.060047e+06  270960.593670  5.078570e+09  4.132460e+09
#
#          Community_    City_Counc    Assembly_D    Asset_Leng    Asset_Widt  \
# count  14718.000000  14718.000000  14718.000000  14718.000000  14718.000000
# mean     348.736377     30.905965     43.011550     26.545536      4.851438
# ...

# %%
# download CSV from source as a CSV
url = "https://data.cityofnewyork.us/api/views/bs59-f3nu/rows.csv"

output_path = "green_infrastructure.csv"

response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    with open(output_path, 'wb') as f:
        f.write(response.content)
    print("CSV file downloaded successfully.")
else:
    print("Failed to download CSV file. Status code:", response.status_code)
# Out:
# CSV file downloaded successfully.

# %%
ls
# Out:
# data-dictionary.xlsx      green-infrastructure.csv  out.csv
# data-download.ipynb       green_infrastructure.csv  out.parquet

# %%
# sanity check
pd.read_csv('green_infrastructure.csv').shape
# Out:
# (14718, 30)

# %% [markdown]
# # Download Data Dictionary

# %%
url = "https://data.cityofnewyork.us/api/views/spjh-pz7h/files/58a6d0ec-f6a0-4ad4-b410-9aa80140d8a4\
# ?download=true&filename=DEPGreenInfrastructure_Data_Dictionary.xlsx"

output_path = "data-dictionary.xlsx"

response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    with open(output_path, 'wb') as f:
        f.write(response.content)
    print("Excel file downloaded successfully.")
else:
    print("Failed to download Excel file. Status code:", response.status_code)
# Out:
# Excel file downloaded successfully.

# %%
ls
# Out:
# data-dictionary.xlsx      green-infrastructure.csv  out.parquet
# data-download.ipynb       out.csv
